# %% [markdown]
# Graphing the label prevelance

# %%
import json
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import hamming_loss, f1_score, precision_score, accuracy_score, recall_score, make_scorer

# %%
label_data = pd.read_csv(f"./random_samples.csv", encoding="utf-8") #import labeled data
y = label_data.iloc[:,3:12]
len(y)
np.mean(y.sum(axis=1))
y.sum(axis=0)
# Out:
# party                   20
# substance_use            6
# sex                     25
# romance                  5
# braggadocio             26
# street_culture          15
# humor                    7
# social_consciousness    18
# introspection            9
# dtype: int64

# %% [markdown]
# Plot Bar Graphs by Theme for each model

# %%
#first, i need to hydrate my predictions
dates = pd.read_json(r'./lyrics-date.json')
dates.loc[dates['era'] == 'Old School', 'date_range'] = "1979 to 1983" #add dates
dates.loc[dates['era'] == 'Golden Age', 'date_range'] = "1983 to 1997"
dates.loc[dates['era'] == 'Bling Era', 'date_range'] = "1997 to 2006"
dates.loc[dates['era'] == 'Blog Era', 'date_range'] = "2006 to 2014"
dates.loc[dates['era'] == 'Rise of Trap', 'date_range'] = "2014 to 2024"

llm_class = pd.read_json(f"./gpt-output/llm_class.json", encoding="utf-8", lines=True, orient='records')
llm_mappings = llm_class.loc[(llm_class['NA'] == False)] #subset for non-NA rows
llm_mappings = llm_mappings.iloc[:,np.r_[1:10, 11]] #only get predictions and id
llm_mappings = llm_mappings.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 14:16]] #get the dates

cc_mappings = pd.read_json(r'feature-mappings.json', lines=True, orient='records') #classifier chain
df2 = pd.DataFrame(cc_mappings["prediction"].to_list(), columns=list(llm_mappings.columns[0:9])) #convert to columns
df2['id'] = cc_mappings['id'] #get the ids
df2 = df2.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 14:16]] #get the dates
df2 = df2.groupby(['era', 'date_range']).sum().reset_index()

# %%
#long data needed

melted = df2.melt(id_vars=['era', 'date_range'], 
                 value_vars=list(df2.iloc[:,1:11].columns),
                 var_name='theme',
                 value_name='count')

# %%
sns.set_theme(style="whitegrid")

# Plot using seaborn's FacetGrid
plt.figure(figsize=(16, 8))
g = sns.FacetGrid(melted, col="date_range", col_wrap=5, 
                  sharey=False, height=4, col_order=['1979 to 1983', '1983 to 1997', '1997 to 2006', '2006 to 2014', '2014 to 2024']) #, col_order=['Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
g.map_dataframe(sns.barplot, x="theme", y="count", dodge=False)
g.set_titles(col_template="Thematic Distribution from {col_name}")
sns.set_theme(font_scale=0.5)
for ax in g.axes.flatten():
    ax.set_xlabel("Theme")
    ax.set_ylabel("Value")
    ax.tick_params(axis='x')
g.set_xticklabels(rotation=45, horizontalalignment='right')
g.add_legend()
#plt.tight_layout()
plt.show()

# %%
llm_mappings = llm_mappings.groupby(['era', 'date_range']).sum().reset_index()
#long data needed

melted = llm_mappings.melt(id_vars=['era', 'date_range'], 
                 value_vars=list(llm_mappings.iloc[:,1:11].columns),
                 var_name='theme',
                 value_name='count')

# %%
# Calculate total count per era
melted['total_in_era'] = melted.groupby('era')['count'].transform('sum')
# Calculate within-group proportion
melted['within_group_proportion'] = melted['count'] / melted['total_in_era']
# Optional: round for readability
melted['within_group_proportion'] = melted['within_group_proportion'].round(3)
#melted['pureile'] = melted[~melted['theme'].isin(['social_consciousness', 'introspection'])]

# %%
melted.sort_values(['era', 'theme'])
# Out:
#              era    date_range                 theme  count  total_in_era  \
# 16     Bling Era  1997 to 2006           braggadocio  162.0         742.0
# 24     Bling Era  1997 to 2006                 humor    5.0         742.0
# 32     Bling Era  1997 to 2006         introspection   36.0         742.0
# 0      Bling Era  1997 to 2006                 party  183.0         742.0
# 12     Bling Era  1997 to 2006               romance   35.0         742.0
# 8      Bling Era  1997 to 2006                   sex  127.0         742.0
# 28     Bling Era  1997 to 2006  social_consciousness  131.0         742.0
# 20     Bling Era  1997 to 2006        street_culture   58.0         742.0
# 4      Bling Era  1997 to 2006         substance_use    5.0         742.0
# 17      Blog Era  2006 to 2014           braggadocio  118.0         604.0
# 25      Blog Era  2006 to 2014                 humor    3.0         604.0
# 33      Blog Era  2006 to 2014         introspection   35.0         604.0
# 1       Blog Era  2006 to 2014                 party  171.0         604.0
# 13      Blog Era  2006 to 2014               romance   30.0         604.0
# 9       Blog Era  2006 to 2014                   sex   85.0         604.0
# 29      Blog Era  2006 to 2014  social_consciousness  108.0         604.0
# 21      Blog Era  2006 to 2014        street_culture   50.0         604.0
# 5       Blog Era  2006 to 2014         substance_use    4.0         604.0
# 18    Golden Age  1983 to 1997           braggadocio  288.0        1393.0
# 26    Golden Age  1983 to 1997                 humor    8.0        1393.0
# 34    Golden Age  1983 to 1997         introspection   65.0        1393.0
# 2     Golden Age  1983 to 1997                 party  409.0        1393.0
# 14    Golden Age  1983 to 1997               romance   65.0        1393.0
# 10    Golden Age  1983 to 1997                   sex  241.0        1393.0
# 30    Golden Age  1983 to 1997  social_consciousness  221.0        1393.0
# 22    Golden Age  1983 to 1997        street_culture   93.0        1393.0
# 6     Golden Age  1983 to 1997         substance_use    3.0        1393.0
# 19  Rise of Trap  2014 to 2024           braggadocio  429.0        2072.0
# 27  Rise of Trap  2014 to 2024                 humor   13.0        2072.0
# 35  Rise of Trap  2014 to 2024         introspection   91.0        2072.0
# 3   Rise of Trap  2014 to 2024                 party  583.0        2072.0
# 15  Rise of Trap  2014 to 2024               romance   82.0        2072.0
# 11  Rise of Trap  2014 to 2024                   sex  362.0        2072.0
# 31  Rise of Trap  2014 to 2024  social_consciousness  360.0        2072.0
# 23  Rise of Trap  2014 to 2024        street_culture  147.0        2072.0
# 7   Rise of Trap  2014 to 2024         substance_use    5.0        2072.0
#
#     within_group_proportion
# 16                    0.218
# 24                    0.007
# 32                    0.049
# 0                     0.247
# 12                    0.047
# 8                     0.171
# 28                    0.177
# 20                    0.078
# 4                     0.007
# 17                    0.195
# 25                    0.005
# 33                    0.058
# 1                     0.283
# 13                    0.050
# 9                     0.141
# 29                    0.179
# 21                    0.083
# 5                     0.007
# 18                    0.207
# 26                    0.006
# 34                    0.047
# 2                     0.294
# 14                    0.047
# 10                    0.173
# 30                    0.159
# 22                    0.067
# 6                     0.002
# 19                    0.207
# 27                    0.006
# 35                    0.044
# 3                     0.281
# 15                    0.040
# 11                    0.175
# 31                    0.174
# 23                    0.071
# 7                     0.002

# %%
sns.set_theme(style="whitegrid")

# Plot using seaborn's FacetGrid
plt.figure(figsize=(8,4))
g = sns.FacetGrid(melted, col="date_range", col_wrap=5, 
                  sharey=False, height=4, col_order=['1979 to 1983', '1983 to 1997', '1997 to 2006', '2006 to 2014', '2014 to 2024']) #, col_order=['Old School', 'Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
g.map_dataframe(sns.barplot, x="theme", y="count", dodge=False)
g.set_titles(col_template="Theme Distribution from {col_name}")
sns.set_theme(font_scale=0.5)
for ax in g.axes.flatten():
    ax.set_xlabel("Theme")
    ax.set_ylabel("Value")
    ax.tick_params(axis='x', rotation=45)
g.set_xticklabels(rotation=45, horizontalalignment='right')
g.add_legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Make line graphs for each model's understandings of the theme

# %%
#first, i need to hydrate my predictions
dates = pd.read_json(r'./lyrics-date.json')
dates.loc[dates['era'] == 'Old School', 'date_range'] = "1979 to 1983" #add dates
dates.loc[dates['era'] == 'Golden Age', 'date_range'] = "1983 to 1997"
dates.loc[dates['era'] == 'Bling Era', 'date_range'] = "1997 to 2006"
dates.loc[dates['era'] == 'Blog Era', 'date_range'] = "2006 to 2014"
dates.loc[dates['era'] == 'Rise of Trap', 'date_range'] = "2014 to 2024"

# %%
llm_class = pd.read_json(f"./gpt-output/llm_class.json", encoding="utf-8", lines=True, orient='records')
llm_mappings = llm_class.loc[(llm_class['NA'] == False)] #subset for non-NA rows
llm_mappings = llm_mappings.iloc[:,np.r_[1:10, 11]] #only get predictions and id
llm_mappings = llm_mappings.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 13:16]] #get the dates
numeric_cols = llm_mappings.select_dtypes(include='boolean').columns
llm_mappings = llm_mappings.groupby(llm_mappings.date.dt.year)[numeric_cols].sum()

# %%
plt.figure(figsize=(8,7))
sns.set_theme(font_scale=0.8)
sns.lineplot(data=llm_mappings)
plt.xlabel("Year")
plt.title("LLM Theme Change over Time")
# Out:
# Text(0.5, 1.0, 'LLM Theme Change over Time')

# %%
cc_mappings = pd.read_json(r'feature-mappings.json', lines=True, orient='records') #classifier chain
df2 = pd.DataFrame(cc_mappings["prediction"].to_list(), columns=list(llm_mappings.columns[0:9])) #convert to columns
df2['id'] = cc_mappings['id'] #get the ids
df2 = df2.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 13:16]] #get the dates
#df2 = df2.groupby(['era', 'date_range']).sum().reset_index()
numeric_cols = df2.select_dtypes(include='number').columns
df2 = df2.groupby(df2.date.dt.year)[numeric_cols].sum()

# %%
plt.figure(figsize=(8,7))
sns.set_theme(font_scale=0.8)
sns.lineplot(data=df2)
plt.xlabel("Year")
plt.title("Classifier Chain Theme Change over Time")
# Out:
# Text(0.5, 1.0, 'Classifier Chain Theme Change over Time')

# %% [markdown]
# Bar graphs to understand the pureile rap scene

# %%
#first, i need to hydrate my predictions
dates = pd.read_json(r'./lyrics-date.json')
dates.loc[dates['era'] == 'Old School', 'date_range'] = "1979 to 1983" #add dates
dates.loc[dates['era'] == 'Golden Age', 'date_range'] = "1983 to 1997"
dates.loc[dates['era'] == 'Bling Era', 'date_range'] = "1997 to 2006"
dates.loc[dates['era'] == 'Blog Era', 'date_range'] = "2006 to 2014"
dates.loc[dates['era'] == 'Rise of Trap', 'date_range'] = "2014 to 2024"

# %%
llm_class = pd.read_json(f"./gpt-output/llm_class.json", encoding="utf-8", lines=True, orient='records')
llm_mappings = llm_class.loc[(llm_class['NA'] == False)] #subset for non-NA rows
llm_mappings = llm_mappings.iloc[:,np.r_[1:10, 11]] #only get predictions and id
llm_mappings = llm_mappings.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 13:16]] #get the dates
#numeric_cols = llm_mappings.select_dtypes(include='boolean').columns
#llm_mappings = llm_mappings.groupby(llm_mappings.date.dt.year)[numeric_cols].sum()

# %%
llm_mappings['pureile'] = (llm_mappings['social_consciousness'] == False) & (llm_mappings['introspection'] == False)
llm_mappings['not_pureile'] = (llm_mappings['social_consciousness'] == True) | (llm_mappings['introspection'] == True)

# %%
numeric_cols = llm_mappings.select_dtypes(include='boolean').columns
llm_mappings = llm_mappings.groupby('era')[numeric_cols].sum()

# %%
llm_mappings.reset_index()
# Out:
#             era  party  substance_use  sex  romance  braggadocio  \
# 0     Bling Era    354            224  150      138          563
# 1      Blog Era    254            156  152      136          441
# 2    Golden Age    420            242  179      144          717
# 3    Old School     83             18   22       30           69
# 4  Rise of Trap    414            518  434      281         1183
#
#    street_culture  humor  social_consciousness  introspection  pureile  \
# 0             600    248                   159            171      479
# 1             382    197                    69            110      402
# 2             733    384                   265            310      639
# 3              69     67                    30             27      112
# 4            1025    420                   199            523      975
#
#    not_pureile
# 0          247
# 1          141
# 2          436
# 3           44
# 4          599

# %%
llm_mappings['pureile'] / (llm_mappings['pureile'] + llm_mappings['not_pureile'])
# Out:
# era
# Bling Era       0.659780
# Blog Era        0.740331
# Golden Age      0.594419
# Old School      0.717949
# Rise of Trap    0.619441
# dtype: float64

# %%
# set the figure size
plt.figure(figsize=(8, 8))
pnp_llm = pd.DataFrame()
# from raw value to percentage
pnp_llm['total_pure'] = llm_mappings['pureile'] / (llm_mappings['pureile'] + llm_mappings['not_pureile'])
pnp_llm['not_pure'] = llm_mappings['not_pureile'] / (llm_mappings['pureile'] + llm_mappings['not_pureile'])
pnp_llm = pnp_llm.reset_index()

# %%
plt.figure(figsize=(8, 8))
custom_order = ['Old School', 'Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
pnp_llm = pnp_llm.set_index('era').loc[custom_order].reset_index()

plt.bar(pnp_llm['era'], pnp_llm['total_pure'], color='darkblue', label='pureile') #['Old School', 'Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
plt.bar(pnp_llm['era'], pnp_llm['not_pure'], bottom=pnp_llm['total_pure'], color='lightblue', label='nonpureile')

# Set y-axis from 0 to 1
plt.ylim(0, 1.0)

# Labels and legend
plt.xlabel("Era")
plt.title("Proportion of 'Pureile' Rap (LLM)")
plt.legend()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cc_mappings = pd.read_json(r'feature-mappings.json', lines=True, orient='records') #classifier chain
df2 = pd.DataFrame(cc_mappings["prediction"].to_list(), columns=list(llm_mappings.columns[0:9])) #convert to columns
df2['id'] = cc_mappings['id'] #get the ids
df2 = df2.merge(dates, how = 'left', on = 'id').iloc[:,np.r_[0:10, 14:16]] #get the dates
#df2 = df2.groupby(['era', 'date_range']).sum().reset_index()

# %%
df2['pureile'] = (df2['social_consciousness'] == False) & (df2['introspection'] == False)
df2['not_pureile'] = (df2['social_consciousness'] == True) | (df2['introspection'] == True)

# %%
numeric_cols = df2.select_dtypes(include='boolean').columns
df2 = df2.groupby('era')[numeric_cols].sum()

# %%
df2['pureile'] / (df2['pureile'] + df2['not_pureile'])
# Out:
# era
# Bling Era       0.794771
# Blog Era        0.788820
# Golden Age      0.817255
# Rise of Trap    0.796498
# dtype: float64

# %%
import matplotlib.patches as mpatches

# set the figure size
plt.figure(figsize=(8, 8))
pnp_cc = pd.DataFrame()
# from raw value to percentage
pnp_cc['total_pure'] = df2['pureile'] / (df2['pureile'] + df2['not_pureile'])
pnp_cc['not_pure'] = df2['not_pureile'] / (df2['pureile'] + df2['not_pureile'])
pnp_cc = pnp_cc.reset_index()

# %%
plt.figure(figsize=(8, 8))
custom_order = ['Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
pnp_cc = pnp_cc.set_index('era').loc[custom_order].reset_index()

plt.bar(pnp_cc['era'], pnp_cc['total_pure'], color='darkblue', label='pureile') #['Old School', 'Golden Age', 'Bling Era', 'Blog Era', 'Rise of Trap']
plt.bar(pnp_cc['era'], pnp_cc['not_pure'], bottom=pnp_cc['total_pure'], color='lightblue', label='nonpureile')

# Set y-axis from 0 to 1
plt.ylim(0, 1.0)

# Labels and legend
plt.xlabel("Era")
plt.title("Proportion of 'Pureile' Rap (CC)")
plt.legend()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
